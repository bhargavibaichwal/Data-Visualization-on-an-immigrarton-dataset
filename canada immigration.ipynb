# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the excel file -and reading the relatable file

# %%
canada=pd.read_excel('Canada.xlsx',sheet_name="Canada by Citizenship",skiprows=range(20),skipfooter=2)
canada.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
canada['AreaName'].value_counts()# how many immigrants from different continents
# Out:
# Africa                             54
# Asia                               49
# Europe                             43
# Latin America and the Caribbean    33
# Oceania                            14
# Northern America                    2
# Name: AreaName, dtype: int64

# %%
canada['OdName'].value_counts().head()
# Out:
# Italy                   1
# Cyprus                  1
# Estonia                 1
# Syrian Arab Republic    1
# Rwanda                  1
# Name: OdName, dtype: int64

# %% [markdown]
# # #1. Draw a line plot for Immigration from Haiti from 2005-2013

# %%
# reading the data

# %%
can=pd.read_excel('Canada.xlsx',sheet_name="Canada by Citizenship",skiprows=range(20),skipfooter=2)
can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
can.rename(columns={"OdName":"Country","AreaName":"Continent","RegName":"Region"},inplace=True)

# %%
can.set_index('Country')
#can.drop(columns=['AREA','REG','DEV'],inplace=True)
# Out:
#                                                           Type    Coverage  \
# Country
# Afghanistan                                         Immigrants  Foreigners
# Albania                                             Immigrants  Foreigners
# Algeria                                             Immigrants  Foreigners
# American Samoa                                      Immigrants  Foreigners
# Andorra                                             Immigrants  Foreigners
# Angola                                              Immigrants  Foreigners
# Antigua and Barbuda                                 Immigrants  Foreigners
# Argentina                                           Immigrants  Foreigners
# Armenia                                             Immigrants  Foreigners
# Australia                                           Immigrants  Foreigners
# Austria                                             Immigrants  Foreigners
# ...

# %%
can['Total']=can.sum(axis=1)
can
# Out:
#            Type    Coverage  \
# 0    Immigrants  Foreigners
# 1    Immigrants  Foreigners
# 2    Immigrants  Foreigners
# 3    Immigrants  Foreigners
# 4    Immigrants  Foreigners
# 5    Immigrants  Foreigners
# 6    Immigrants  Foreigners
# 7    Immigrants  Foreigners
# 8    Immigrants  Foreigners
# 9    Immigrants  Foreigners
# 10   Immigrants  Foreigners
# 11   Immigrants  Foreigners
# 12   Immigrants  Foreigners
# 13   Immigrants  Foreigners
# 14   Immigrants  Foreigners
# 15   Immigrants  Foreigners
# 16   Immigrants  Foreigners
# 17   Immigrants  Foreigners
# 18   Immigrants  Foreigners
# 19   Immigrants  Foreigners
# 20   Immigrants  Foreigners
# 21   Immigrants  Foreigners
# 22   Immigrants  Foreigners
# 23   Immigrants  Foreigners
# 24   Immigrants  Foreigners
# 25   Immigrants  Foreigners
# 26   Immigrants  Foreigners
# 27   Immigrants  Foreigners
# 28   Immigrants  Foreigners
# 29   Immigrants  Foreigners
# ..          ...         ...
# 165  Immigrants  Foreigners
# ...

# %%
# finding null values
can.isnull().sum()
# Out:
# Type         0
# Coverage     0
# Country      0
# AREA         0
# Continent    0
# REG          0
# Region       0
# DEV          0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
can1=can[['Country',1980,1981,1982,1983,1984,1985]]
can1
# Out:
#                                                Country   1980   1981   1982  \
# 0                                          Afghanistan     16     39     39
# 1                                              Albania      1      0      0
# 2                                              Algeria     80     67     71
# 3                                       American Samoa      0      1      0
# 4                                              Andorra      0      0      0
# 5                                               Angola      1      3      6
# 6                                  Antigua and Barbuda      0      0      0
# 7                                            Argentina    368    426    626
# 8                                              Armenia      0      0      0
# 9                                            Australia    702    639    484
# 10                                             Austria    234    238    201
# ...

# %%
# find data of american Samoa Country
print(can.loc[3])
# Out:
# Type                 Immigrants
# Coverage             Foreigners
# Country          American Samoa
# AREA                        909
# Continent               Oceania
# REG                         957
# Region                Polynesia
# DEV                         902
# DevName      Developing regions
# 1980                          0
# 1981                          1
# 1982                          0
# 1983                          0
# 1984                          0
# 1985                          0
# 1986                          0
# 1987                          1
# 1988                          0
# 1989                          1
# 1990                          2
# 1991                          0
# 1992                          0
# 1993                          0
# 1994                          0
# 1995                          0
# 1996                          0
# 1997                          0
# 1998                          0
# 1999                          0
# ...

# %%
can.set_index('Country',inplace=True)

# %%
# find data of Algeria Country
print(can.loc['Algeria'])
# Out:
# Type                 Immigrants
# Coverage             Foreigners
# AREA                        903
# Continent                Africa
# REG                         912
# Region          Northern Africa
# DEV                         902
# DevName      Developing regions
# 1980                         80
# 1981                         67
# 1982                         71
# 1983                         69
# 1984                         63
# 1985                         44
# 1986                         69
# 1987                        132
# 1988                        242
# 1989                        434
# 1990                        491
# 1991                        872
# 1992                        795
# 1993                        717
# 1994                        595
# 1995                       1106
# 1996                       2054
# 1997                       1842
# 1998                       2292
# 1999                       2389
# 2000                       2867
# ...

# %%
# find data of Japan from 1989-1984
can.loc['Japan',[1980,1981,1982,1983,1984]]
# Out:
# 1980    701
# 1981    756
# 1982    598
# 1983    309
# 1984    246
# Name: Japan, dtype: object

# %%
# if country is equal to Asia the True else False
can['Continent']=='Asia'
# Out:
# Country
# Afghanistan                                              True
# Albania                                                 False
# Algeria                                                 False
# American Samoa                                          False
# Andorra                                                 False
# Angola                                                  False
# Antigua and Barbuda                                     False
# Argentina                                               False
# Armenia                                                  True
# Australia                                               False
# Austria                                                 False
# Azerbaijan                                               True
# Bahamas                                                 False
# Bahrain                                                  True
# Bangladesh                                               True
# ...

# %%
sns.set()
haiti=can.loc['Haiti',[2005,2006,2007,2008,2009,2010,2011,2012,2013]]
plt.text(2010,5000,'2010 Earthquake')
haiti.plot(kind='line')

# %% [markdown]
# ## 3.plot line graph for immigration India,China from 1980 to 2013

# %%
years=[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013]
can1=can.loc[['India','China'],years]
can1.head()
# Out:
#          1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# Country                                                                 ...
# India    8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
# China    5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
#
#           2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# Country
# India    28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
# China    36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
#
# [2 rows x 34 columns]

# %%
can1.plot(kind='line')

# %%
# .....doubt
india=can.loc['India',[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013]]
china=can.loc['China',[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013]]
china.plot(kind='line')
india.plot(kind='line')
plt.xlabel('immigrants')# no of immigrants
plt.legend()

# %%
can1.transpose().head()
# Out:
# Country  India  China
# 1980      8880   5123
# 1981      8670   6682
# 1982      8147   3308
# 1983      7338   1863
# 1984      5704   1527

# %%
#year=list(map(str,range(1980,2014)))## try it out
#year
#year=can.columns=list(map(str,can.columns))

# %% [markdown]
# # 5.6. Compare the trend of top 5 countries

# %%
#can['Total'].nlargest(5)

# %%
#figure=can['Total'].nlargest(5).plot(kind='line')

# %%
can.sort_values(by='Total',ascending=False,axis=0,inplace=True)
can2=can.head()
can2
# Out:
#                                                           Type    Coverage  \
# Country
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
#
#                                                     AREA Continent   REG  \
# Country
# India                                                935      Asia  5501
# China                                                935      Asia   906
# United Kingdom of Great Britain and Northern Ir...   908    Europe   924
# Philippines                                          935      Asia   920
# Pakistan                                             935      Asia  5501
#
# ...

# %%
can3=can2[years].transpose()
can3.plot(kind='line',figsize=(15,4))

# %% [markdown]
# # 7 plot area plot for Immigration Trend of Top 5 Countries

# %%
can3.plot(kind='area',figsize=(15,4),stacked=False)
plt.xlabel('years')
plt.ylabel('Number of immigrants')
plt.title('immigration trend of top 5 countries')
# Out:
# Text(0.5, 1.0, 'immigration trend of top 5 countries')

# %% [markdown]
# # 8.9. Use the scripting layer to create a stacked area plot of the 5 countries that contributed the least to immigration to Canada from 1980 to 2013. Use a transparency value of 0.45.

# %% [markdown]
# canada_new=can.sort_values(by='Total',ascending=True,axis=0,inplace=True)
# canada_new

# %%
#can.drop(columns=['AREA'])
#can.sort_values(by='Total',ascending=True,axis=0)
can4=can.tail()
can4
# Out:
#                              Type    Coverage  AREA         Continent  REG  \
# Country
# New Caledonia          Immigrants  Foreigners   909           Oceania  928
# San Marino             Immigrants  Foreigners   908            Europe  925
# Canada                 Immigrants    Citizens   905  Northern America  905
# Sao Tome and Principe  Immigrants  Foreigners   903            Africa  911
# Western Sahara         Immigrants  Foreigners   903            Africa  912
#
#                                  Region  DEV             DevName  1980  1981  \
# Country
# New Caledonia                 Melanesia  902  Developing regions     0     0
# San Marino              Southern Europe  901   Developed regions     1     0
# Canada                 Northern America  901   Developed regions     0     0
# Sao Tome and Principe     Middle Africa  902  Developing regions     0     0
# Western Sahara          Northern Africa  902  Developing regions     0     0
#
# ...

# %%
# this is artist

# %%
can5=can4[years].transpose()
can5.plot(kind='area',alpha=0.45,stacked=False)

# %%
# this is scripting

# %%
can5.plot(kind='area',stacked=True,alpha=0.55)

# %% [markdown]
# # 10.What is the frequency distribution of the number (population) of new immigrants from the various countries to Canada in 2013?

# %%
can[2013].head()
# Out:
# Country
# India                                                   33087
# China                                                   34129
# United Kingdom of Great Britain and Northern Ireland     5827
# Philippines                                             29544
# Pakistan                                                12603
# Name: 2013, dtype: int64

# %%
can[2013].plot.hist()

# %%
import numpy as np
count, bin_edges=np.histogram(can[2013])
print(count)
print(bin_edges)
# Out:
# [178  11   1   2   0   0   0   0   1   2]
# [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %%
can[2013].plot(kind='hist',figsize=(8,5),xticks=bin_edges)
plt.show()

# %% [markdown]
# # 11.What is the immigration distribution for Denmark, Norway, and Sweden for years 1980 - 2013?

# %%
denmark=can.loc[['Denmark','Norway','Sweden'],years]
denmark.transpose().plot.hist()

# %% [markdown]
# # 12.Use the scripting layer to display the immigration distribution for Greece, Albania, and Bulgaria for years 1980 - 2013? Use an overlapping plot with 15 bins and a transparency value of 0.35.

# %%
greece=can.loc[['Greece','Albania','Bulgaria'],years]
greece
# Out:
#           1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                               ...
# Greece    1065   953   897   633   580   584   547   765   564   773  ...
# Albania      1     0     0     0     0     0     1     2     2     3  ...
# Bulgaria    24    20    12    33    11    24    33    52    43    85  ...
#
#           2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Greece     120   100    74   110   107   119   101   102   146   298
# Albania   1450  1223   856   702   560   716   561   539   620   603
# Bulgaria  2022  1738  1419  1172   994   784   556   365   451   512
#
# [3 rows x 34 columns]

# %%
count, bin_edges=np.histogram(greece,15)
greece.transpose().plot(kind='hist',bins=15,xticks=bin_edges,figsize=(15,4),alpha=0.35,color=['coral','darkslateblue','mediumseagreen'])

# %%
import matplotlib
for name,hex in matplotlib.colors.cnames.items():
    print(name,hex)
# Out:
# aliceblue #F0F8FF
# antiquewhite #FAEBD7
# aqua #00FFFF
# aquamarine #7FFFD4
# azure #F0FFFF
# beige #F5F5DC
# bisque #FFE4C4
# black #000000
# blanchedalmond #FFEBCD
# blue #0000FF
# blueviolet #8A2BE2
# brown #A52A2A
# burlywood #DEB887
# cadetblue #5F9EA0
# chartreuse #7FFF00
# chocolate #D2691E
# coral #FF7F50
# cornflowerblue #6495ED
# cornsilk #FFF8DC
# crimson #DC143C
# cyan #00FFFF
# darkblue #00008B
# darkcyan #008B8B
# darkgoldenrod #B8860B
# darkgray #A9A9A9
# darkgreen #006400
# darkgrey #A9A9A9
# darkkhaki #BDB76B
# darkmagenta #8B008B
# darkolivegreen #556B2F
# darkorange #FF8C00
# darkorchid #9932CC
# darkred #8B0000
# darksalmon #E9967A
# darkseagreen #8FBC8F
# darkslateblue #483D8B
# darkslategray #2F4F4F
# darkslategrey #2F4F4F
# darkturquoise #00CED1
# darkviolet #9400D3
# deeppink #FF1493
# deepskyblue #00BFFF
# dimgray #696969
# dimgrey #696969
# dodgerblue #1E90FF
# firebrick #B22222
# floralwhite #FFFAF0
# forestgreen #228B22
# fuchsia #FF00FF
# ...

# %% [markdown]
# # 13.Compare the number of Icelandic immigrants (country = 'Iceland') to Canada from year 1980 to 2013.

# %%
iceland=can.loc[['Iceland'],years]
iceland.transpose().plot(kind='bar',figsize=(10,6),color=['darkred'])
plt.annotate('',xy=(32,70),xytext=(28,20),xycoords='data',# this is used to add an arrow in the plot
             arrowprops=dict(arrowstyle='->',connectionstyle='arc3',color='blue'))
plt.annotate('2008-2011 financial Crisis',
            xy=(28,30),
            rotation=72.5,
            va='bottom',
            ha='left',)
# Out:
# Text(28, 30, '2008-2011 financial Crisis')

# %% [markdown]
# ## 14.Using the scripting layer and the df dataset, create a horizontal bar plot showing the total number of immigrants to Canada from the top 15 countries, for the period 1980 - 2013. Label each country with the total immigrant count.

# %%
cann2=can['Total'].nlargest(15)
cann2.plot(kind='barh',stacked=True,figsize=(10,6),alpha=0.55)
plt.xlabel('Number of Immigrants')
plt.title('top 15 countries cotributing to immigration of canada')
count=0
for val in cann2:
    plt.annotate(val,xy=(val+10000,count),color='black')
    count=count+1
plt.show()
#another way
# can.sort_values(by='Total',ascending=true,inplace=True)
#can15=

# %% [markdown]
# ## 15. Box plot of Japanese Immigrants from 1980 - 2013

# %%
can.loc['Japan',years].plot(kind='box')
plt.title('Immigrants from japan')
plt.ylabel('number of immigrants')
# Out:
# Text(0, 0.5, 'number of immigrants')

# %% [markdown]
# ## 16. Box Plots of Immigrants from China and India (1980 - 2013)

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)
china1=can.loc[['India','China'],years]
china1.transpose().plot(kind='box',vert=False,ax=ax0,figsize=(20,6),title='box plot for immigrants from India and china')
china1.transpose().plot(kind='line',ax=ax1,figsize=(20,6),title='line plot for immigrants from india and china')

# %% [markdown]
# ## 17. plot scatter for Total Immigration to Canada from 1980 - 2013

# %%
df_tot=pd.DataFrame(can[years].sum(axis=0))
df_tot.reset_index(inplace=True)
df_tot.columns=['years','total']
df_tot.head()
df_tot.years=list(map(int,df_tot.years))

# %%
#df_tot.years=list(map(int,df_tot.years))# converting the year column to integer
df_tot.head()
df_tot.plot(kind='scatter',x='years',y='total',color='blue')

# %% [markdown]
# ## 18. plot line graph Total Immigration to Canada from 1980 - 2013

# %%
df_tot['total'].plot(kind='line')

# %% [markdown]
# ## 19. Create a scatter plot of the total immigration from Denmark, Norway, and Sweden to Canada from 1980 to 2013?

# %% [markdown]
# ## --visiualise for top 5 cotinents

# %%
can.set_index('Continent',inplace=True)

# %%
df_continents=can.groupby('Continent',axis=0).sum()# first group the continents
df_continents.head()
# Out:
#                                   AREA     REG    DEV   1980   1981   1982  \
# Continent
# Africa                           48762   49242  48708   3951   4363   3819
# Asia                             45815  109147  44197  31025  34314  30214
# Europe                           39044   39754  38743  39760  44802  42720
# Latin America and the Caribbean  29832   30395  29766  13081  15215  16769
# Northern America                  1810    1810   1802   9378  10030   9074
#
#                                   1983   1984   1985   1986  ...    2005  \
# Continent                                                    ...
# Africa                            2671   2639   2650   3782  ...   27523
# Asia                             24696  27274  23850  28739  ...  159253
# Europe                           24638  22287  20844  24370  ...   35955
# Latin America and the Caribbean  15427  13678  15171  21179  ...   24747
# Northern America                  7100   6661   6543   7074  ...    8394
# ...

# %%
# now calling the column
df_continents['Total'].plot(kind='pie',
                           figsize=(7,6),
                           autopct='%1.2f%%',# show the decimal point
                            startangle=90,
                           shadow=True)

# %%
# for slicing the pie plot 
colors_list=['gold','yellowgreen','lightcoral','lightskyblue','lightgreen','red']
explode_list=[0.3,0,0,0,0,0]# ratio for each continent
df_continents['Total'].plot(kind='pie',
                           figsize=(6,6),
                           autopct='%1.2f%%',# show the decimal point
                            startangle=90,
                           shadow=True,
                           labels=None,# removed the labels
                           colors=colors_list,
                           explode=explode_list,
                           pctdistance=0.8)# changes the place of the  label
